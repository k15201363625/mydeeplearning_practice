# %% [markdown]
# # 卷积神经网络进阶
# - AlexNet
#     - 引爆点
# - VGG
#     - 加宽 加深
# - ResNet
#     - 残差连接块
# - InCeptionNet
#     - 加宽 分组卷积
#     - 强联手 v4=res+inc v3实用性很棒
# - MobileNet
#     - 移动端 实用性 分组卷积
# - NesNet
#     - 自我学习 AUTOML
#
#
# > 原因：
#     - 解决问题不同
#     - 使用技巧不同
#     - 应用场景不同

# %% [markdown]
# ## 模型对比选择
# ### 概述
# - 目前最好的 inceptionv4(80%) resnet新版(82%)
# - alexnet < 55%
# - 但是对比参数计算量 实用性更强的是Inceptionv3
# - 每个模型都有自己的更新迭代
# ### 对比展示
# - ![Snipaste_2019-07-06_15-25-37.png](attachment:Snipaste_2019-07-06_15-25-37.png)
#
#
# - ![Snipaste_2019-07-06_15-26-27.png](attachment:Snipaste_2019-07-06_15-26-27.png)
#
#
# - ![Snipaste_2019-07-06_15-26-57.png](attachment:Snipaste_2019-07-06_15-26-57.png)
